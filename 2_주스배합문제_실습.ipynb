# %% [markdown]
# ![Screenshot 2025-09-28 at 11.41.37 AM.png](data:image/png;base64,...)

# %% [markdown]
# **데이터**

# %%
stock = { 'strawberry': 800, 'banana': 600, 'cherry': 400, 'apple': 500 }
juices = [ 'A', 'B', 'C', 'D' ]
recipes = {
    ('A', 'banana'): .2, ('A', 'strawberry'): .6, ('A', 'cherry'): .2, ('A', 'apple'): .0,
    ('B', 'banana'): .4, ('B', 'strawberry'): .3, ('B', 'cherry'): .0, ('B', 'apple'): .3,
    ('C', 'banana'): .3, ('C', 'strawberry'): .0, ('C', 'cherry'): .2, ('C', 'apple'): .5,
    ('D', 'banana'): .0, ('D', 'strawberry'): .2, ('D', 'cherry'): .5, ('D', 'apple'): .3,
}
prices = { 'A': 3, 'B': 4, 'C': 2, 'D': 1 }

# %% [markdown]
# **gurobipy 설치 및 패키지 불러오기**

# %%
# gurobipy 설치 및 패키지 불러오는 코드, 기억하시나요?

# %% [markdown]
# **수리 모델링 및 구현**

# %%
'''
model = gp.Model("juice_blending")      # 모델
x = model.addVars(juices, obj=prices)   # 결정 변수 + 목적 함수
model.ModelSense = gp.GRB.MAXIMIZE      # 최적화 방향
'''
# Out:
# '\nmodel = gp.Model("juice_blending")      # 모델\nx = model.addVars(juices, obj=prices)   # 결정 변수 + 목적 함수\nmodel.ModelSense = gp.GRB.MAXIMIZE      # 최적화 방향\n'

# %%
# 제약 조건을 구현하세요.

# %%
'''
model.optimize()
for juice in juices:
  print(juice, x[juice].X)
print(model.ObjVal)
'''
# Out:
# '\nmodel.optimize()\nfor juice in juices:\n  print(juice, x[juice].X)\nprint(model.ObjVal)\n'
