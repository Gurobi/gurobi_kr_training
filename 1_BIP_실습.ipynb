# %% [markdown]
# Binary Integer Program
#
# \begin{align}
#         \text{max }x+ y+ 2z \\
#         x + 2y + 3z \le 4 \\
#         x + y \ge 1 \\
#         x,y,z \in \{0, 1\}
# \end{align}

# %% [markdown]
# **gurobipy 설치 및 패키지 불러오기**

# %%
# !pip install gurobipy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 86.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# **모델 선언**

# %% [markdown]
# **결정 변수**

# %% [markdown]
# **목적 함수**

# %% [markdown]
# **제약 조건**

# %% [markdown]
# **Gurobi Optimizer 실행**

# %% [markdown]
# **최적화 상태 확인**

# %% [markdown]
# **해 확인**
